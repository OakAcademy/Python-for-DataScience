# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
EPL = pd.read_csv("2006-2018 EPL stats.csv")

# %%
EPL
# Out:
#                          team  wins  losses  goals  total_yel_card  \
# 0           Manchester United  28.0     5.0   83.0            60.0
# 1                     Chelsea  24.0     3.0   64.0            62.0
# 2                   Liverpool  20.0    10.0   57.0            44.0
# 3                     Arsenal  19.0     8.0   63.0            59.0
# 4           Tottenham Hotspur  17.0    12.0   57.0            48.0
# 5            Bolton Wanderers  16.0    14.0   47.0            84.0
# 6                     Reading  16.0    15.0   52.0            38.0
# 7            Blackburn Rovers  15.0    16.0   52.0            77.0
# 8                     Everton  15.0    10.0   52.0            65.0
# 9                  Portsmouth  14.0    12.0   45.0            48.0
# 10              Middlesbrough  12.0    16.0   44.0            64.0
# 11            West Ham United  12.0    21.0   35.0            85.0
# 12                Aston Villa  11.0    10.0   43.0            48.0
# ...

# %%
EPL.count()
# Out:
# team                    240
# wins                    240
# losses                  240
# goals                   240
# total_yel_card          240
# total_red_card          240
# total_scoring_att       240
# ontarget_scoring_att    240
# hit_woodwork            240
# att_hd_goal             240
# att_pen_goal            240
# att_freekick_goal       240
# att_ibox_goal           240
# att_obox_goal           240
# goal_fastbreak          240
# total_offside           240
# clean_sheet             240
# goals_conceded          240
# saves                   220
# outfielder_block        240
# interception            240
# total_tackle            240
# last_man_tackle         240
# total_clearance         240
# head_clearance          220
# own_goals               240
# penalty_conceded        240
# pen_goals_conceded      240
# total_pass              240
# total_through_ball      220
# total_long_balls        240
# backward_pass           160
# total_cross             240
# ...

# %%
EPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 42 columns):
# team                    240 non-null object
# wins                    240 non-null float64
# losses                  240 non-null float64
# goals                   240 non-null float64
# total_yel_card          240 non-null float64
# total_red_card          240 non-null float64
# total_scoring_att       240 non-null float64
# ontarget_scoring_att    240 non-null float64
# hit_woodwork            240 non-null float64
# att_hd_goal             240 non-null float64
# att_pen_goal            240 non-null float64
# att_freekick_goal       240 non-null float64
# att_ibox_goal           240 non-null float64
# att_obox_goal           240 non-null float64
# goal_fastbreak          240 non-null float64
# total_offside           240 non-null float64
# clean_sheet             240 non-null float64
# goals_conceded          240 non-null float64
# ...

# %%
print(EPL.shape)
# Out:
# (240, 42)

# %%
Man_U = EPL.groupby("team").get_group("Manchester United")

# %%
Man_U
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 20   Manchester United  27.0     5.0   80.0            51.0             2.0
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 61   Manchester United  27.0     7.0   86.0            49.0             4.0
# 80   Manchester United  23.0     4.0   78.0            56.0             3.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
# 146  Manchester United  19.0    12.0   64.0            66.0             3.0
# 163  Manchester United  20.0     8.0   62.0            64.0             5.0
# 183  Manchester United  19.0    10.0   49.0            65.0             1.0
# 205  Manchester United  18.0     5.0   54.0            78.0             2.0
# ...

# %%
Man_U["wins"].max()
# Out:
# 28.0

# %%
Man_U[Man_U["wins"].max()==Man_U["wins"]]
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0                698.0                 256.0          21.0         12.0  ...
# 40               715.0                 230.0           9.0          7.0  ...
# 101              646.0                 243.0          17.0         16.0  ...
# 120              561.0                 213.0          24.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 0          918.0         258.0  25686.0                NaN
# 40        1039.0         257.0  30077.0                NaN
# ...

# %%
Man_U = Man_U.groupby("season").get_group("2008-2009")

# %%
Man_U
# Out:
#                  team  wins  losses  goals  total_yel_card  total_red_card  \
# 40  Manchester United  28.0     4.0   68.0            61.0             5.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 40              715.0                 230.0           9.0          7.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 40       1039.0         257.0  30077.0                NaN                 3.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 40         579.0           0.0              56.0     22.0  2008-2009
#
# [1 rows x 42 columns]

# %%
Man_C = EPL.groupby("team").get_group("Manchester City")

# %%
Man_C
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 13   Manchester City  11.0    18.0   29.0            59.0             4.0
# 28   Manchester City  15.0    13.0   45.0            50.0             4.0
# 46   Manchester City  15.0    18.0   58.0            49.0             4.0
# 65   Manchester City  18.0     7.0   73.0            49.0             2.0
# 82   Manchester City  21.0     9.0   60.0            71.0             5.0
# 100  Manchester City  28.0     5.0   93.0            51.0             5.0
# 121  Manchester City  23.0     6.0   66.0            62.0             3.0
# 140  Manchester City  27.0     6.0  102.0            72.0             1.0
# 161  Manchester City  24.0     7.0   83.0            77.0             2.0
# 182  Manchester City  19.0    10.0   71.0            61.0             0.0
# 203  Manchester City  23.0     6.0   80.0            71.0             4.0
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
# ...

# %%
Man_C["wins"].max()
# Out:
# 32.0

# %%
Man_C[Man_C["wins"].max()==Man_C["wins"]]
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 220        691.0         284.0  35130.0               63.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 220                 4.0         406.0           2.0              21.0
#
#      punches     season
# 220     15.0  2017-2018
#
# [1 rows x 42 columns]

# %%
Man_C = Man_C.groupby("season").get_group("2017-2018")

# %%
LIV = EPL.groupby("team").get_group("Liverpool")

# %%
LIV
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 2    Liverpool  20.0    10.0   57.0            44.0             0.0
# 23   Liverpool  21.0     4.0   67.0            45.0             1.0
# 42   Liverpool  25.0     2.0   77.0            50.0             0.0
# 64   Liverpool  18.0    11.0   61.0            55.0             5.0
# 84   Liverpool  17.0    14.0   59.0            63.0             2.0
# 108  Liverpool  14.0    14.0   47.0            53.0             5.0
# 126  Liverpool  16.0     9.0   71.0            54.0             2.0
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
# 165  Liverpool  18.0    12.0   52.0            66.0             3.0
# 186  Liverpool  16.0    10.0   63.0            61.0             3.0
# 204  Liverpool  22.0     6.0   78.0            54.0             0.0
# 224  Liverpool  21.0     5.0   84.0            44.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# ...

# %%
LIV["wins"].max()
# Out:
# 26.0

# %%
LIV[LIV["wins"].max()==LIV["wins"]]
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 141              651.0                 258.0          27.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 141        643.0         224.0  28172.0               64.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 141                 5.0         427.0           1.0              36.0
#
#      punches     season
# 141     29.0  2013-2014
#
# [1 rows x 42 columns]

# %%
LIV = LIV.groupby("season").get_group("2013-2014")

# %%
CHE = EPL.groupby("team").get_group("Chelsea")

# %%
CHE
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 1    Chelsea  24.0     3.0   64.0            62.0             4.0
# 21   Chelsea  25.0     3.0   65.0            63.0             5.0
# 41   Chelsea  25.0     5.0   68.0            50.0             3.0
# 60   Chelsea  27.0     6.0  103.0            54.0             5.0
# 81   Chelsea  21.0     9.0   69.0            59.0             1.0
# 105  Chelsea  18.0    10.0   65.0            74.0             4.0
# 122  Chelsea  22.0     7.0   75.0            51.0             3.0
# 142  Chelsea  25.0     6.0   71.0            57.0             3.0
# 160  Chelsea  26.0     3.0   73.0            73.0             4.0
# 189  Chelsea  12.0    12.0   59.0            58.0             5.0
# 200  Chelsea  30.0     5.0   85.0            72.0             0.0
# 223  Chelsea  21.0    10.0   62.0            42.0             4.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# ...

# %%
CHE["wins"].max()
# Out:
# 30.0

# %%
CHE[CHE["wins"].max() == CHE["wins"]]
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 200  Chelsea  30.0     5.0   85.0            72.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 200              580.0                 204.0          17.0          8.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 200        688.0         218.0  27658.0               32.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 200                 3.0         436.0           0.0              38.0
#
#      punches     season
# 200     18.0  2016-2017
#
# [1 rows x 42 columns]

# %%
CHE = CHE.groupby("season").get_group("2016-2017")

# %%
ARS=EPL.groupby("team").get_group("Arsenal")

# %%
ARS
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 3    Arsenal  19.0     8.0   63.0            59.0             3.0
# 22   Arsenal  24.0     3.0   74.0            55.0             3.0
# 43   Arsenal  20.0     6.0   68.0            58.0             3.0
# 62   Arsenal  23.0     9.0   83.0            56.0             1.0
# 83   Arsenal  19.0     8.0   72.0            65.0             6.0
# 102  Arsenal  21.0    10.0   74.0            64.0             4.0
# 123  Arsenal  21.0     7.0   72.0            42.0             5.0
# 143  Arsenal  24.0     7.0   68.0            53.0             4.0
# 162  Arsenal  22.0     7.0   71.0            68.0             2.0
# 181  Arsenal  20.0     7.0   65.0            40.0             4.0
# 202  Arsenal  23.0     9.0   77.0            68.0             3.0
# 225  Arsenal  19.0    13.0   74.0            57.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# ...

# %%
ARS["wins"].max()
# Out:
# 24.0

# %%
ARS[ARS["wins"].max()==ARS["wins"]]
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 22   Arsenal  24.0     3.0   74.0            55.0             3.0
# 143  Arsenal  24.0     7.0   68.0            53.0             4.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 22               627.0                 208.0          13.0         14.0  ...
# 143              523.0                 213.0          15.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 22         888.0         234.0  28156.0                NaN
# 143        753.0         210.0  29825.0               50.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 22                  2.0         776.0           1.0              45.0
# 143                 3.0         367.0           1.0              70.0
#
#      punches     season
# 22      26.0  2007-2008
# 143     27.0  2013-2014
#
# [2 rows x 42 columns]

# %%
ARS = ARS.groupby("season").get_group("2007-2008")

# %%
ARS
# Out:
#        team  wins  losses  goals  total_yel_card  total_red_card  \
# 22  Arsenal  24.0     3.0   74.0            55.0             3.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 22              627.0                 208.0          13.0         14.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 22        888.0         234.0  28156.0                NaN                 2.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 22         776.0           1.0              45.0     26.0  2007-2008
#
# [1 rows x 42 columns]

# %%
TOT = EPL.groupby("team").get_group("Tottenham Hotspur")

# %%
TOT
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 4    Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
# 32   Tottenham Hotspur  11.0    14.0   66.0            51.0             1.0
# 48   Tottenham Hotspur  14.0    15.0   45.0            54.0             5.0
# 63   Tottenham Hotspur  21.0    10.0   67.0            58.0             1.0
# 85   Tottenham Hotspur  16.0     8.0   55.0            51.0             2.0
# 103  Tottenham Hotspur  20.0     9.0   66.0            43.0             3.0
# 124  Tottenham Hotspur  21.0     8.0   66.0            55.0             2.0
# 145  Tottenham Hotspur  21.0    11.0   55.0            66.0             4.0
# 164  Tottenham Hotspur  19.0    12.0   58.0            79.0             4.0
# 184  Tottenham Hotspur  19.0     6.0   69.0            72.0             0.0
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
# ...

# %%
TOT["wins"].max()
# Out:
# 26.0

# %%
TOT[TOT["wins"].max()==TOT["wins"]]
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 201              669.0                 257.0          22.0         10.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 201        761.0         273.0  28150.0               41.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 201                 1.0         484.0           0.0              21.0
#
#      punches     season
# 201     11.0  2016-2017
#
# [1 rows x 42 columns]

# %%
TOT = TOT.groupby("season").get_group("2016-2017")

# %%
Top_Teams = pd.concat([Man_U,Man_C,CHE,LIV,ARS,TOT])

# %%
Top_Teams
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 220    Manchester City  32.0     2.0  106.0            59.0             2.0
# 200            Chelsea  30.0     5.0   85.0            72.0             0.0
# 141          Liverpool  26.0     6.0  101.0            54.0             1.0
# 22             Arsenal  24.0     3.0   74.0            55.0             3.0
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 40               715.0                 230.0           9.0          7.0  ...
# 220              665.0                 265.0          23.0         12.0  ...
# 200              580.0                 204.0          17.0          8.0  ...
# 141              651.0                 258.0          27.0         14.0  ...
# ...

# %%
Top_Teams["wins"].max()
# Out:
# 32.0

# %%
Top_Teams[Top_Teams["wins"].max()== Top_Teams["wins"]]
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 220        691.0         284.0  35130.0               63.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 220                 4.0         406.0           2.0              21.0
#
#      punches     season
# 220     15.0  2017-2018
#
# [1 rows x 42 columns]

# %%
Top_Teams["losses"].max()
# Out:
# 6.0

# %%
Top_Teams[Top_Teams["losses"].max()==Top_Teams["losses"]]
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 141              651.0                 258.0          27.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 141        643.0         224.0  28172.0               64.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 141                 5.0         427.0           1.0              36.0
#
#      punches     season
# 141     29.0  2013-2014
#
# [1 rows x 42 columns]

# %%
EPL["ontarget_scoring_att"].max()
# Out:
# 288.0

# %%
EPL[EPL["ontarget_scoring_att"].max() == EPL["ontarget_scoring_att"]]
# Out:
#        team  wins  losses  goals  total_yel_card  total_red_card  \
# 60  Chelsea  27.0     6.0  103.0            54.0             5.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 60              834.0                 288.0          13.0         16.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 60       1083.0         286.0  28914.0                NaN                 3.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 60         503.0           1.0              87.0     30.0  2009-2010
#
# [1 rows x 42 columns]

# %%
Top_Teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 40 to 201
# Data columns (total 42 columns):
# team                    6 non-null object
# wins                    6 non-null float64
# losses                  6 non-null float64
# goals                   6 non-null float64
# total_yel_card          6 non-null float64
# total_red_card          6 non-null float64
# total_scoring_att       6 non-null float64
# ontarget_scoring_att    6 non-null float64
# hit_woodwork            6 non-null float64
# att_hd_goal             6 non-null float64
# att_pen_goal            6 non-null float64
# att_freekick_goal       6 non-null float64
# att_ibox_goal           6 non-null float64
# att_obox_goal           6 non-null float64
# goal_fastbreak          6 non-null float64
# total_offside           6 non-null float64
# clean_sheet             6 non-null float64
# goals_conceded          6 non-null float64
# saves                   5 non-null float64
# ...

# %%
Top_Teams["Penalty_S_R"]=((Top_Teams.penalty_save / Top_Teams.penalty_conceded) *100).astype(int)

# %%
Top_Teams
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 220    Manchester City  32.0     2.0  106.0            59.0             2.0
# 200            Chelsea  30.0     5.0   85.0            72.0             0.0
# 141          Liverpool  26.0     6.0  101.0            54.0             1.0
# 22             Arsenal  24.0     3.0   74.0            55.0             3.0
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 40               715.0                 230.0           9.0          7.0  ...
# 220              665.0                 265.0          23.0         12.0  ...
# 200              580.0                 204.0          17.0          8.0  ...
# 141              651.0                 258.0          27.0         14.0  ...
# ...

# %%
Top_Teams["Penalty_S_R"].max()
# Out:
# 100

# %%
Top_Teams[Top_Teams["Penalty_S_R"].max()==Top_Teams["Penalty_S_R"]]
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      corner_taken  touches  big_chance_missed  clearance_off_line  \
# 220         284.0  35130.0               63.0                 4.0
#
#      dispossessed  penalty_save  total_high_claim  punches     season  \
# 220         406.0           2.0              21.0     15.0  2017-2018
#
#      Penalty_S_R
# 220          100
#
# [1 rows x 43 columns]

# %%
Labels = ["Man_U","Man_C","CHE","LIV","ARS","TOT"]

# %%
Figure,Axes = plt.subplots(figsize = (14,7))

Axes.bar(Top_Teams["season"],Top_Teams["wins"])
Axes.set_ylabel("Seasons")
Axes.set_xlabel("Wins Count")
Axes.set_xticklabels(Labels)
plt.show()

# %%
Labels = ["Man_U","Man_C","CHE","LIV","ARS","TOT"]

# %%
Figure_2, Axes_2 = plt.subplots(figsize=(14,9))

Axes_2.pie(Top_Teams["total_scoring_att"],labels = Labels, autopct = "%1.1f%%", explode = [0.1,0,0.1,0,0.1,0])
Axes_2.legend()
plt.show()
